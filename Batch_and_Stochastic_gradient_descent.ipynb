# %%
import pandas as pd

# %%
df = pd.read_csv('gd_sgd_dataset.csv')

# %%
df.shape
# Out:
# (1000, 8)

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns = 'salary')
y = df['salary']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2 , random_state = 42)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(128, activation = 'relu', input_dim = x_train.shape[1]))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# **Batch_size = 1 means stochastic gradient descent**
#
# **batch_size = x_train.shape[0] means batch gradient descent**

# %%
model.fit(x_train, y_train, epochs = 10, batch_size = 1000, validation_split = 0.2)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step - accuracy: 0.0000e+00 - loss: -1285522456576.0000 - val_accuracy: 0.0000e+00 - val_loss: -1100835454976.0000
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.0000e+00 - loss: -1285756157952.0000 - val_accuracy: 0.0000e+00 - val_loss: -1101033766912.0000
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.0000e+00 - loss: -1285986844672.0000 - val_accuracy: 0.0000e+00 - val_loss: -1101229719552.0000
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.0000e+00 - loss: -1286214778880.0000 - val_accuracy: 0.0000e+00 - val_loss: -1101423443968.0000
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.0000e+00 - loss: -1286440353792.0000 - val_accuracy: 0.0000e+00 - val_loss: -1101615202304.0000
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.0000e+00 - loss: -1286663569408.0000 - val_accuracy: 0.0000e+00 - val_loss: -1101805125632.0000
# Epoch 7/10
# ...

# %%
df
# Out:
#      age  experience  education_years  hours_per_week  performance  \
# 0     50          29               16            56.8          1.6
# 1     36          14               16            31.9          4.0
# 2     29           7               16            56.5          1.6
# 3     42          20               18            43.4          9.8
# 4     40          18               12            45.3          8.4
# ..   ...         ...              ...             ...          ...
# 995   34          13               12            56.9          5.5
# 996   51          29               12            48.7          3.6
# 997   44          24               16            59.2          7.6
# 998   40          20               14            44.0          1.2
# 999   53          33               16            55.4          6.3
#
#      certifications  distance_km    salary
# 0                 2         48.9  59759.96
# 1                 4         10.2  38913.37
# ...
